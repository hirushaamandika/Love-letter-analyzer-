# %%
# !pip install scikit-learn pandas matplotlib nltk joblib

import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import MultinomialNB
from sklearn.metrics import classification_report
import joblib

# %%
data = {
    "text": [
        # Romantic lines
        "You are the sunshine of my life",
        "I miss you every heartbeat",
        "My love for you grows every day",
        "I will always be yours",
        "Every heartbeat whispers your name",
        "You are my forever",
        "I dream of you every night",
        "Without you, I am incomplete",
        "You are my soulmate",
        "I cherish every moment with you",
        "My heart belongs to you",
        "You are the reason I smile",
        "I can’t stop thinking about you",
        "You make my world brighter",
        "I love you endlessly",

        # Neutral lines
        "The capital of France is Paris",
        "Water boils at 100 degrees Celsius",
        "Python is a programming language",
        "The sky is blue today",
        "The train leaves at 6 PM",
        "Water freezes at 0 degrees Celsius",
        "Dogs are loyal animals",
        "The Earth revolves around the Sun",
        "Apples are rich in vitamins",
        "The library opens at 9 AM",
        "The weather is cloudy today",
        "Mathematics is the study of numbers",
        "The computer is running fast",
        "The book is on the table",
        "The meeting starts at noon"
    ],
    "label": [
        "romantic","romantic","romantic","romantic","romantic",
        "romantic","romantic","romantic","romantic","romantic",
        "romantic","romantic","romantic","romantic","romantic",
        "neutral","neutral","neutral","neutral","neutral",
        "neutral","neutral","neutral","neutral","neutral",
        "neutral","neutral","neutral","neutral","neutral"
    ]
}

df = pd.DataFrame(data)
df.head()
# Out:
#                                  text     label
# 0     You are the sunshine of my life  romantic
# 1          I miss you every heartbeat  romantic
# 2     My love for you grows every day  romantic
# 3              I will always be yours  romantic
# 4  Every heartbeat whispers your name  romantic

# %%
vectorizer = TfidfVectorizer(stop_words='english', ngram_range=(1,2))
X = vectorizer.fit_transform(df['text'])
y = df['label']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

model = MultinomialNB()
model.fit(X_train, y_train)
# Out:
# MultinomialNB()

# %%
y_pred = model.predict(X_test)
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#      neutral       0.00      0.00      0.00         6
#     romantic       0.33      1.00      0.50         3
#
#     accuracy                           0.33         9
#    macro avg       0.17      0.50      0.25         9
# weighted avg       0.11      0.33      0.17         9
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# ...

# %%
samples = [
    "I will love you forever",
    "The weather is cloudy today",
    "You are my heartbeat",
    "My soul longs for you",
    "The train leaves at 6 PM"
]

print(model.predict(vectorizer.transform(samples)))
# Out:
# ['romantic' 'neutral' 'romantic' 'romantic' 'neutral']

# %%
import joblib
joblib.dump(model, "love_model.pkl")
joblib.dump(vectorizer, "vectorizer.pkl")
# Out:
# ['vectorizer.pkl']

# %%
# !pip install gradio
import gradio as gr

model = joblib.load("love_model.pkl")
vectorizer = joblib.load("vectorizer.pkl")

def analyze_text(text):
    prediction = model.predict(vectorizer.transform([text]))
    return "💖 Romantic" if prediction[0] == "romantic" else "🙂 Neutral"

iface = gr.Interface(
    fn=analyze_text,
    inputs="text",
    outputs="text",
    title="Love Letter Sentiment Analyzer 💌",
    description="Type a love line and see if AI thinks it's romantic!"
)

iface.launch(share=True)  # gives you a public link
# Out:
# ...
# Colab notebook detected. To show errors in colab notebook, set debug=True in launch()
# * Running on public URL: https://95bd39dafbde657e78.gradio.live
#
# This share link expires in 1 week. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://95bd39dafbde657e78.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
